# %%
import datetime
import tensorflow as tf
import numpy as np

# %%
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# ## Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# ### Normalizing Data
#     By normalizing data [0,1], we are ensuring that the NN trains faster

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
x_train = x_train.reshape(-1, 28*28) #-1 means all elements of an array
x_train.shape
# Out:
# (60000, 784)

# %%
x_test = x_test.reshape(-1, 28*28)

# %% [markdown]
# ## Creating Model

# %%
model = tf.keras.models.Sequential() #instance of the Sequential class

# %% [markdown]
# ### First fully connected hidden layer
# - number of neurons:128
# - activiation function: ReLU (Use when building dense layer) (dense layer means each input connected to each output)
# - input_shape (784,)

# %%
model.add(tf.keras.layers.Dense(units=128, activation="relu", input_shape=(784, )))

# %%
model.add(tf.keras.layers.Dense(units=128, activation="relu", input_shape=(784, )))

# %% [markdown]
# ### Dropout
# - a regularization technique that reduces chances of overfitting by "dropping" a certain random percent of neurons.
# - This means that we set them to zero, and thus they will not be updated.
# - Makes training process longer
# - usually 20 - 50%
# - connections are determined only on input

# %%
model.add(tf.keras.layers.Dropout(0.3))

# %%
model.add(tf.keras.layers.Dense(units=128, activation="relu", input_shape=(784, )))

# %% [markdown]
# ### Output Layer
# - units is equal to the number of classes. 10 in this case.
# - activation: softmax
# - You are in essence creating 10 different probabilities and chosing the highest

# %%
model.add(tf.keras.layers.Dense(units=10, activation="softmax"))

# %% [markdown]
# ## Compiling Model
# - Optimizer: Adam
# - Loss: Sparse softmax (categorical) crossentropy
# - binary class is "accuracy", but more than 2 is "sparse_categorical_accuracy"

# %%
model.compile(optimizer="adamax", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 134,794
# Trainable params: 134,794
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 60us/sample - loss: 2.2546 - sparse_categorical_accuracy: 0.1581
# Epoch 2/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 2.0794 - sparse_categorical_accuracy: 0.3007
# Epoch 3/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 1.9111 - sparse_categorical_accuracy: 0.4072
# Epoch 4/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 1.7443 - sparse_categorical_accuracy: 0.4707
# Epoch 5/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 1.5937 - sparse_categorical_accuracy: 0.5100
# Epoch 6/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 1.4591 - sparse_categorical_accuracy: 0.5472
# Epoch 7/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 1.3505 - sparse_categorical_accuracy: 0.5732
# Epoch 8/10
# 60000/60000 [==============================] - 4s 59us/sample - loss: 1.2630 - sparse_categorical_accuracy: 0.5918
# Epoch 9/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 1.1964 - sparse_categorical_accuracy: 0.6046
# Epoch 10/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 1.1394 - sparse_categorical_accuracy: 0.6159

# %% [markdown]
# ## Evaluating Neural Net

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
